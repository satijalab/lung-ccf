# %% [markdown]
# # Solving 3D Poisson on Allen CCF
#
# - Download Allen CCF from [link](http://download.alleninstitute.org/informatics-archive/current-release/mouse_ccf/average_template/average_template_10.nrrd)

# %%
import fenics as fe
import mshr
import cv2
import nrrd
import ipyvolume as ipy

# %%
# load ccf
path = '/Users/tbiancal/datasets/brain/download.alleninstitute.org/informatics-archive/current-release/mouse_ccf/average_template/average_template_100.nrrd'
vol, _ = nrrd.read(path)
vol.shape, vol.dtype
# Out:
# ((132, 80, 114), dtype('uint16'))

# %%
vol_1d = np.reshape(vol, newshape=(-1,))
plt.hist(vol_1d);

# %%
seg = vol < 6
plt.imshow(seg[50])

# %%
ipy.quickvolshow(seg)
# Out:
# /Users/tbiancal/miniconda3/envs/pde/lib/python3.7/site-packages/ipyvolume/serialize.py:81: RuntimeWarning: invalid value encountered in true_divide
#   gradient = gradient / np.sqrt(gradient[0]**2 + gradient[1]**2 + gradient[2]**2)
# ...
